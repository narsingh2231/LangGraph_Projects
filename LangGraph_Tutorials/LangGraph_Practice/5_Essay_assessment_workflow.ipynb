# %%
from langgraph.graph import StateGraph, START, END
from pydantic import BaseModel, Field
from typing import TypedDict

from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()

model= ChatGroq(model="llama-3.3-70b-versatile")   # model= "openai/gpt-oss-120b" ---- This is not working well for structured output

# %%
class EvaluationSchema(BaseModel):
    
    feedback: str = Field(
        description='Detailed feedback for the essay'
    )
    score:int = Field(
        description='score out of 10', ge=0, le=10
    )

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay= """# **Democracy Without Accountability is a Ticking Time Bomb**

## Introduction

Abraham Lincoln famously defined democracy as "government of the people, by the people, for the people." However, democracy is not merely a system of periodic elections; it is a continuous process of responsible governance. While democracy empowers citizens by granting them political rights and freedoms, accountability ensures that this power is exercised responsibly and in accordance with constitutional principles. Democracy without accountability is akin to a powerful engine without brakes—it may move swiftly, but eventually it is destined to crash.

The essence of democratic governance lies not only in popular sovereignty but also in ensuring that those entrusted with authority remain answerable for their actions. When accountability weakens, democratic institutions become vulnerable to corruption, abuse of power, erosion of public trust, and ultimately authoritarian tendencies. Thus, democracy without accountability indeed becomes a ticking time bomb waiting to explode into political instability and social unrest.

---

## Democracy and Accountability: Two Sides of the Same Coin

Democracy rests on the principles of liberty, equality, participation, and justice. Accountability complements these ideals by ensuring transparency, responsiveness, and ethical governance.

Political accountability requires elected representatives to answer to citizens.

Administrative accountability ensures that bureaucracy remains impartial and efficient.

Judicial accountability guarantees that justice is delivered fairly without compromising judicial independence.

Financial accountability ensures prudent utilization of public resources.

Social accountability empowers citizens, media, and civil society to monitor governance.

In essence, democracy provides power, whereas accountability provides legitimacy.

---

## Why Accountability is the Soul of Democracy

### Accountability Prevents Abuse of Power

Lord Acton's famous observation, "Power tends to corrupt, and absolute power corrupts absolutely," remains profoundly relevant. Without institutional checks, elected governments may gradually centralize authority, suppress dissent, and undermine constitutional values.

The Constitution of India incorporates multiple mechanisms such as separation of powers, judicial review, federalism, parliamentary oversight, and independent constitutional bodies precisely to prevent arbitrary exercise of power.

---

### Accountability Strengthens Public Trust

Democratic institutions derive legitimacy from citizens' confidence. When governments remain transparent regarding policies, expenditures, and decision-making processes, public trust deepens.

Conversely, opaque governance breeds suspicion, conspiracy theories, and alienation, weakening the democratic fabric.

As former President A.P.J. Abdul Kalam observed:

*"Transparency and accountability are essential for good governance."*

---

### Accountability Ensures Efficient Governance

Governments accountable to citizens become more responsive to public needs.

Schemes like Direct Benefit Transfer (DBT), digital governance, Public Financial Management Systems, and social audits have significantly reduced leakages and improved service delivery by making governance more transparent.

---

### Accountability Protects Fundamental Rights

Unchecked governments may curtail civil liberties in the name of security, nationalism, or development.

Independent courts, vigilant media, active civil society, and constitutional watchdogs ensure that democratic majorities do not become instruments of majoritarian oppression.

Democracy is not simply majority rule; it is majority rule restrained by constitutional morality.

---

## Consequences of Democracy Without Accountability

### Rise of Corruption

Lack of accountability encourages rent-seeking, nepotism, favoritism, and misuse of public funds.

Corruption diverts scarce resources away from education, healthcare, infrastructure, and welfare, disproportionately harming the poor.

As Kautilya remarked in the Arthashastra:

*"Just as one cannot know when a fish drinks water, one cannot know when an official steals public money."*

His solution was continuous oversight—not blind trust.

---

### Democratic Backsliding

Many countries continue to conduct elections while simultaneously weakening independent institutions, intimidating the media, and concentrating executive power.

Such systems retain democratic appearances but gradually lose democratic substance.

This phenomenon is often described as "electoral authoritarianism."

---

### Erosion of Institutional Integrity

Democracy depends more upon institutions than individuals.

When constitutional bodies become politicized or ineffective, institutional decline accelerates.

Weak institutions eventually become incapable of restraining executive excesses.

---

### Populism and Majoritarianism

Without accountability, political leaders may increasingly appeal to emotions rather than evidence.

Short-term populist promises replace long-term policy reforms.

Majoritarian politics may marginalize minorities, weakening constitutional democracy.

Dr. B.R. Ambedkar cautioned that democracy in India must rest not merely on political equality but also on constitutional morality.

---

### Decline in Citizen Participation

Citizens lose faith when governments fail to respond to grievances.

Declining voter turnout, political apathy, protests, and social unrest often indicate democratic dissatisfaction rather than democratic health.

When peaceful democratic channels fail, extra-constitutional methods begin to emerge.

Thus, accountability acts as a safety valve preventing democratic frustration from turning explosive.

---

## Accountability Mechanisms in India

India has developed multiple institutional safeguards.

### Constitutional Institutions

* Parliament
* Judiciary
* Election Commission
* Comptroller and Auditor General (CAG)
* Finance Commission
* Union Public Service Commission

Each institution contributes uniquely to maintaining constitutional accountability.

---

### Legislative Oversight

Question Hour, Zero Hour, Parliamentary Committees, Public Accounts Committee, Estimates Committee, and debates ensure executive scrutiny.

Although disruptions sometimes reduce parliamentary productivity, committee systems continue to strengthen legislative accountability.

---

### Judicial Accountability

Judicial review acts as the guardian of constitutional supremacy.

The Supreme Court and High Courts have expanded accountability through Public Interest Litigation (PIL), environmental jurisprudence, and protection of fundamental rights.

---

### Transparency Laws

The Right to Information Act transformed governance by empowering ordinary citizens to seek official information.

It democratized transparency and reduced administrative secrecy.

Similarly, proactive disclosure under digital governance initiatives has increased citizen participation.

---

### Social Accountability

Civil society organizations, investigative journalism, social media, citizen report cards, and social audits have emerged as important instruments of democratic accountability.

The Mahatma Gandhi National Rural Employment Guarantee Act institutionalized social audits, enabling communities to directly monitor public expenditure.

---

## Emerging Challenges to Accountability

### Digital Misinformation

Social media has democratized expression but has also amplified fake news, deepfakes, and information manipulation.

Without responsible digital governance, public opinion itself may become distorted.

---

### Criminalization of Politics

Candidates facing serious criminal charges weaken democratic credibility.

Electoral reforms remain necessary to ensure cleaner politics.

---

### Money Power

Excessive election expenditure increases dependence on private funding and corporate influence, creating unequal political competition.

Political finance reforms remain central to strengthening accountability.

---

### Weak Local Governance

Democracy becomes meaningful only when accountability reaches the grassroots.

Despite constitutional status under the 73rd and 74th Amendments, many local bodies continue to suffer from inadequate finances, limited autonomy, and administrative dependence.

---

## Accountability Beyond Government

Democracy requires accountability not only from governments but also from citizens.

Citizens must:

* Vote responsibly.
* Pay taxes honestly.
* Reject misinformation.
* Respect constitutional values.
* Participate in public discourse.
* Hold representatives accountable beyond elections.

Similarly, media, judiciary, bureaucracy, corporations, political parties, and civil society must all remain accountable.

Rights without duties weaken democracy just as authority without responsibility weakens governance.

---

## The Way Forward

Strengthening accountability requires a comprehensive approach:

* Deepening transparency through technology and open data.
* Strengthening parliamentary functioning.
* Ensuring judicial efficiency while preserving judicial independence.
* Protecting institutional autonomy.
* Reforming political funding.
* Encouraging ethical leadership.
* Expanding civic education.
* Promoting evidence-based policymaking.
* Empowering local governments.
* Leveraging Artificial Intelligence responsibly for transparent governance while protecting privacy and civil liberties.

Ultimately, constitutional morality must prevail over political expediency.

---

## Conclusion

Democracy survives not because citizens vote once every few years but because institutions remain continuously accountable. Elections confer authority, but accountability confers legitimacy. When governments cease to answer questions, institutions lose independence, media loses freedom, and citizens lose trust, democracy gradually transforms into an empty shell.

The strength of a democracy is measured not by the power of its rulers but by the effectiveness of the mechanisms that restrain that power. Accountability is therefore not an obstacle to governance; it is its greatest safeguard.

As Dr. B.R. Ambedkar wisely warned, constitutional democracy can endure only when those in power remain bound by constitutional morality rather than the temptation of unchecked authority.

A democracy without accountability may appear stable for a time, but beneath the surface it accumulates injustice, corruption, and public resentment. Like a ticking time bomb, it carries within itself the seeds of its own destruction. Only through transparency, responsibility, institutional integrity, and active citizenship can democracy remain resilient, inclusive, and worthy of the faith reposed in it by the people.


"""

# %%
prompt = f"Evaluate the language quality of following essay and provide a feedback and assign a score out of 10 \n {essay}"
structured_model.invoke(prompt)
# Out:
# EvaluationSchema(feedback='The essay is well‑structured, with a clear hierarchy of headings that guide the reader through a logical progression from introduction to conclusion. The language is generally formal and appropriate for an academic‑policy discussion, and the writer demonstrates a good command of terminology related to democracy and accountability. Strengths include:\n- Effective use of analogies (e.g., “engine without brakes”) and quotations that reinforce key points.\n- Consistent parallelism in lists (e.g., the four types of accountability) which improves readability.\n- Integration of Indian examples (CAG, DBT, RTI, etc.) that ground the argument in concrete evidence.\n\nAreas for improvement:\n1. **Repetition and Redundancy** – Certain ideas are restated in successive sections (e.g., the link between transparency and trust appears multiple times) which could be consolidated for tighter prose.\n2. **Citation Style** – References to historical figures (Lord Acton, Kautily
# ...

# %%
import operator
from typing import Annotated

# %%
# State

class UPSCState(TypedDict):
    essay: str
    language_feedback:str
    analysis_feedback:str
    clarity_feedback:str
    overall_feedback:str
    
    individual_scores: Annotated[list[int], operator.add]
    avg_score:float

# %%
#functions

def evaluate_language(state:UPSCState):
    
    prompt = f"Evaluate the language quality of following essay and provide a feedback and assign a score out of 10  \n {state['essay']}"
    output = structured_model.invoke(prompt)
    
    return {'language_feedback': output.feedback,
    'individual_scores':[output.score]
    }
    
    
def evaluate_analysis(state: UPSCState):
    
    prompt = f"Evaluate the depth of analysis of following essay and provide a feedback and assign a score out of 10  \n {state['essay']}"
    output = structured_model.invoke(prompt)
    
    return {
    'analysis_feedback': output.feedback,
    'individual_scores':[output.score]
    }
     
    
def evaluate_thought(state: UPSCState):
    
    prompt = f"Evaluate the clarity of thought of following essay and provide a feedback and assign a score out of 10 \n {state['essay']}"
    output = structured_model.invoke(prompt)
    
    return {
    'clarity_feedback': output.feedback ,
    'individual_scores':[output.score]
    }
    
    
    
def final_evaluation(state: UPSCState):
    
    prompt = f"Based on the following feedback provide a summarised feedback \n langauage feedback {state["language_feedback"]}, \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state['clarity_feedback']}"
    output = model.invoke(prompt)                                                                                                                                                   
    
    avg_score= sum(state['individual_scores'] )/ len((state['individual_scores'] ))                                                                                                                                               
    
    return {
    'overall_feedback':output.content,
    'avg_score': avg_score}

# %%
# graph
graph = StateGraph(UPSCState)

# nodes
graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)

#Edges

graph.add_edge(START, 'evaluate_language')
graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_thought')

graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')

graph.add_edge('final_evaluation',END)


graph.compile()

# %%
workflow= graph.compile()

# %%
initial_state= {
    'essay':essay
}

final_state= workflow.invoke(initial_state)

final_state
# Out:
# {'essay': '# **Democracy Without Accountability is a Ticking Time Bomb**\n\n## Introduction\n\nAbraham Lincoln famously defined democracy as "government of the people, by the people, for the people." However, democracy is not merely a system of periodic elections; it is a continuous process of responsible governance. While democracy empowers citizens by granting them political rights and freedoms, accountability ensures that this power is exercised responsibly and in accordance with constitutional principles. Democracy without accountability is akin to a powerful engine without brakes—it may move swiftly, but eventually it is destined to crash.\n\nThe essence of democratic governance lies not only in popular sovereignty but also in ensuring that those entrusted with authority remain answerable for their actions. When accountability weakens, democratic institutions become vulnerable to corruption, abuse of power, erosion of public trust, and ultimately authoritarian tendencies. Thus, 
# ...

# %%
essay2= """Artificial Intelligence is growing in India very fast. AI is everywhere and every company is using AI because AI is the future. India is also making AI and many students are learning AI nowadays. This is very good because AI is useful in many things.

Government is also supporting AI. Many startups are opening and they are making AI products. This helps the economy and creates jobs. AI is used in hospitals, schools, farming and many other places. Farmers can use AI to grow more crops and students can use AI to study better. Therefore AI is helping everyone.

But there are some problems also. AI can take jobs from people. Some people may become unemployed. There are also privacy issues because AI uses data. Government should make some rules for AI. If there are rules then AI will become safe.

India has many engineers so India can become number one in AI. Many foreign companies are investing in India because Indians are talented. AI can increase GDP and make India a developed country. We should all learn AI because AI is important. Every student should study AI from school because AI is the future and AI will solve many problems.

In conclusion, AI is good and bad but mostly good. India should develop AI as much as possible. AI will make India stronger and better. AI is the future so everyone should support AI.

"""

# %%
initial_state= {
    'essay':essay2
}

final_state= workflow.invoke(initial_state)

final_state
# Out:
# {'essay': 'Artificial Intelligence is growing in India very fast. AI is everywhere and every company is using AI because AI is the future. India is also making AI and many students are learning AI nowadays. This is very good because AI is useful in many things.\n\nGovernment is also supporting AI. Many startups are opening and they are making AI products. This helps the economy and creates jobs. AI is used in hospitals, schools, farming and many other places. Farmers can use AI to grow more crops and students can use AI to study better. Therefore AI is helping everyone.\n\nBut there are some problems also. AI can take jobs from people. Some people may become unemployed. There are also privacy issues because AI uses data. Government should make some rules for AI. If there are rules then AI will become safe.\n\nIndia has many engineers so India can become number one in AI. Many foreign companies are investing in India because Indians are talented. AI can increase GDP and make India a d
# ...

# %%
essay3 = """ # Artificial Intelligence Development in India

Artificial Intelligence is one of the most important technology in today's world. Many countries are working on AI because it is very useful and it can do many things. India is also developing AI and many people are talking about it. Nowadays AI is becoming popular because it is helping people in different fields. Every company wants to use AI because it saves time and increases work efficiency. Therefore, AI development in India is growing very fast.

India has many software engineers and IT companies. These people are learning AI and making different AI applications. Many colleges have also started AI courses because students are interested in this field. Students think AI will give them good jobs in future. Many online platforms also teach AI, so anyone can learn it from home. This is a good thing because more people are becoming skilled in AI.

The government is also supporting AI development. There are different programs and initiatives for promoting AI. Government wants India to become a global leader in Artificial Intelligence. Many startups are getting funding and trying to make AI products. Some startups are making chatbots while others are making healthcare or education solutions. This is increasing innovation in the country and making India more modern.

AI is useful in many sectors. In healthcare, doctors can use AI to detect diseases quickly. In education, students can use AI to understand difficult topics. Farmers can use AI to predict weather and improve farming. Banks can use AI to detect fraud. Companies use AI to answer customer questions through chatbots. Because AI is useful everywhere, it is becoming an important technology for everyone. Many people are using AI every day without even knowing it.

However, AI also has some disadvantages. One major problem is unemployment because AI can replace many workers. If companies use AI for everything, then many employees may lose their jobs. This can become a serious problem in future. Another problem is privacy because AI needs a lot of data. If personal information is not protected, people may face many issues. Therefore, government should make strong rules for AI so that it is used properly.

Although India is making progress, there are still many challenges. Many villages do not have good internet connection, so people cannot use AI properly. Some schools also do not have computers or trained teachers. Because of this, not everyone can learn AI equally. There is also lack of awareness among many people. They think AI is only for software engineers, but actually AI can help everyone if it is used correctly.

India has a large population and many talented young people. Because of this, India can become one of the best AI countries in the world. Many international companies are investing in India because Indian engineers are hardworking and talented. If investment continues, AI industry will grow even faster. More jobs will be created and the economy will become stronger. AI can also improve public services and make people's lives easier.

In conclusion, Artificial Intelligence is growing rapidly in India and it has many advantages. It is helping different sectors and creating new opportunities. At the same time, there are problems like unemployment, privacy issues and lack of awareness. These problems should be solved by making proper rules and providing education. Overall, AI is good for India and everyone should support AI because it is the future. If India continues to develop AI, then India will become a developed country and AI will solve many problems for the nation.


"""

# %%
initial_state= {
    'essay':essay3
}

final_state= workflow.invoke(initial_state)

final_state
# Out:
# {'essay': " # Artificial Intelligence Development in India\n\nArtificial Intelligence is one of the most important technology in today's world. Many countries are working on AI because it is very useful and it can do many things. India is also developing AI and many people are talking about it. Nowadays AI is becoming popular because it is helping people in different fields. Every company wants to use AI because it saves time and increases work efficiency. Therefore, AI development in India is growing very fast.\n\nIndia has many software engineers and IT companies. These people are learning AI and making different AI applications. Many colleges have also started AI courses because students are interested in this field. Students think AI will give them good jobs in future. Many online platforms also teach AI, so anyone can learn it from home. This is a good thing because more people are becoming skilled in AI.\n\nThe government is also supporting AI development. There are different p
# ...

# %%
essay4= """ # The First War Between India and Pakistan (1947–1948)

The first war between India and Pakistan took place shortly after the partition of British India in 1947. The conflict, commonly known as the First Indo-Pak War or the Kashmir War of 1947–48, was fought over the princely state of Jammu and Kashmir. This war not only shaped the future relationship between the two newly independent nations but also created one of the longest-running territorial disputes in modern history.

At the time of independence, princely states were given the choice to join either India or Pakistan. Jammu and Kashmir was ruled by Maharaja Hari Singh, who initially decided to remain independent. However, the situation changed rapidly in October 1947 when tribal militias from Pakistan's North-West Frontier, supported by elements from Pakistan, entered Kashmir. Their objective was to seize the territory before a formal decision regarding accession could be made.

As the tribal forces advanced toward Srinagar, the Maharaja sought military assistance from India. The Government of India agreed to provide support after the Maharaja signed the Instrument of Accession, legally acceding Jammu and Kashmir to India on 26 October 1947. Following this, Indian troops were airlifted to Srinagar and began military operations to defend the region.

The war witnessed intense fighting across mountainous terrain. Indian forces successfully secured Srinagar and pushed back the invading forces from several strategic locations. Battles were fought in regions such as Uri, Poonch, and Ladakh. Both sides suffered significant military and civilian casualties. The difficult geography, harsh weather, and logistical challenges made the conflict particularly demanding for the soldiers.

As the war continued, the issue attracted international attention. India referred the matter to the United Nations in January 1948, seeking intervention to restore peace. The United Nations called for a ceasefire and proposed measures that included the withdrawal of forces and the possibility of a plebiscite under certain conditions. However, disagreements over the implementation of these conditions prevented the proposal from being fully realized.

A UN-mediated ceasefire came into effect on 1 January 1949. By the end of the conflict, India retained control over approximately two-thirds of the former princely state, including the Kashmir Valley, Jammu, and Ladakh. Pakistan remained in control of the remaining western and northern regions, which it administers today as Azad Jammu and Kashmir and Gilgit-Baltistan. The ceasefire line established after the war later evolved into the Line of Control (LoC), which continues to divide the region.

The First Indo-Pak War had lasting consequences for South Asia. It laid the foundation for future conflicts between India and Pakistan, including the wars of 1965, 1971, and the Kargil conflict of 1999. The Kashmir dispute remains a significant issue in bilateral relations and has influenced the political, military, and diplomatic policies of both countries for decades.

The war also highlighted the importance of national security, military preparedness, and effective diplomacy for newly independent nations. It demonstrated how unresolved political issues at the time of partition could evolve into prolonged international disputes. Furthermore, it underscored the role of international organizations such as the United Nations in conflict resolution, while also revealing the limitations of external mediation in complex geopolitical conflicts.

In conclusion, the First Indo-Pak War of 1947–48 was a defining event in the history of both India and Pakistan. It established the framework for the Kashmir dispute that continues to influence regional politics today. Understanding the causes, events, and consequences of this conflict is essential for appreciating the complexities of South Asian history and the importance of peaceful dialogue in resolving long-standing disputes.
"""

# %%
initial_state= {
    'essay':essay4
}

final_state= workflow.invoke(initial_state)

final_state
# Out:
# {'essay': " # The First War Between India and Pakistan (1947–1948)\n\nThe first war between India and Pakistan took place shortly after the partition of British India in 1947. The conflict, commonly known as the First Indo-Pak War or the Kashmir War of 1947–48, was fought over the princely state of Jammu and Kashmir. This war not only shaped the future relationship between the two newly independent nations but also created one of the longest-running territorial disputes in modern history.\n\nAt the time of independence, princely states were given the choice to join either India or Pakistan. Jammu and Kashmir was ruled by Maharaja Hari Singh, who initially decided to remain independent. However, the situation changed rapidly in October 1947 when tribal militias from Pakistan's North-West Frontier, supported by elements from Pakistan, entered Kashmir. Their objective was to seize the territory before a formal decision regarding accession could be made.\n\nAs the tribal forces advanced 
# ...
